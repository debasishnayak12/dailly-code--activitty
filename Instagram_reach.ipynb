# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from wordcloud) (1.25.1)
# Requirement already satisfied: pillow in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from wordcloud) (10.0.0)
# Requirement already satisfied: matplotlib in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from matplotlib->wordcloud) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from matplotlib->wordcloud) (6.0.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\madhu\anaconda3\envs\debu\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator

# %%
# import data and libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("instagram_reach.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  S.No              USERNAME  \
# 0           0     1         mikequindazzi
# 1           1     2       drgorillapaints
# 2           2     3    aitrading_official
# 3           3     4  opensourcedworkplace
# 4           4     5           crea.vision
#
#                                              Caption  Followers  \
# 0  Who are #DataScientist and what do they do? >>...       1600
# 1  We all know where it’s going. We just have to ...        880
# 2  Alexander Barinov: 4 years as CFO in multinati...        255
# 3                                               sfad        340
# 4  Ever missed a call while your phone was chargi...        304
#
#                                             Hashtags Time since posted  Likes
# 0  #MachineLearning #AI #DataAnalytics #DataScien...          11 hours    139
# 1   #deck .#mac #macintosh#sayhello #apple #steve...           2 hours     23
# 2  #whoiswho #aitrading #ai #aitradingteam#instat...           2 hours     25
# 3  #iot #cre#workplace #CDO #bigdata #technology#...           3 hours     49
# 4  #instamachinelearning #instabigdata#instamarke...           3 hours     30

# %%
data=data.drop(labels=["Unnamed: 0","S.No"],axis=1)

# %%
data.head()
# Out:
#                USERNAME                                            Caption  \
# 0         mikequindazzi  Who are #DataScientist and what do they do? >>...
# 1       drgorillapaints  We all know where it’s going. We just have to ...
# 2    aitrading_official  Alexander Barinov: 4 years as CFO in multinati...
# 3  opensourcedworkplace                                               sfad
# 4           crea.vision  Ever missed a call while your phone was chargi...
#
#    Followers                                           Hashtags  \
# 0       1600  #MachineLearning #AI #DataAnalytics #DataScien...
# 1        880   #deck .#mac #macintosh#sayhello #apple #steve...
# 2        255  #whoiswho #aitrading #ai #aitradingteam#instat...
# 3        340  #iot #cre#workplace #CDO #bigdata #technology#...
# 4        304  #instamachinelearning #instabigdata#instamarke...
#
#   Time since posted  Likes
# 0          11 hours    139
# 1           2 hours     23
# 2           2 hours     25
# 3           3 hours     49
# 4           3 hours     30

# %%
data.shape
# Out:
# (100, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   USERNAME           100 non-null    object
#  1   Caption            94 non-null     object
#  2   Followers          100 non-null    int64
#  3   Hashtags           100 non-null    object
#  4   Time since posted  100 non-null    object
#  5   Likes              100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
data.isnull().sum()
# Out:
# USERNAME             0
# Caption              6
# Followers            0
# Hashtags             0
# Time since posted    0
# Likes                0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (94, 6)

# %%
data.isnull().sum()
# Out:
# USERNAME             0
# Caption              0
# Followers            0
# Hashtags             0
# Time since posted    0
# Likes                0
# dtype: int64

# %%
#plot heatmap
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#import libraries from wordcloud
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
text=' '.join(i for i in data.Hashtags)
stopwords=set(STOPWORDS)
wordcloud=WordCloud(stopwords=stopwords,background_color="White").generate(text)
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
data.columns
# Out:
# Index(['USERNAME', 'Caption', 'Followers', 'Hashtags', 'Time since posted',
#        'Likes'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split

# %%
data.dtypes
# Out:
# USERNAME             object
# Caption              object
# Followers             int64
# Hashtags             object
# Time since posted    object
# Likes                 int64
# dtype: object

# %%
l=LabelEncoder()
data["USERNAME"]=l.fit_transform(data["USERNAME"])
data["Caption"]=l.fit_transform(data["Caption"])
data["Hashtags"]=l.fit_transform(data["Hashtags"])

# %%
data.head()
# Out:
#    USERNAME  Caption  Followers  Hashtags Time since posted  Likes
# 0        61       86       1600        14          11 hours    139
# 1        28       82        880        91           2 hours     23
# 2         3       13        255        82           2 hours     25
# 3        67       89        340        61           3 hours     49
# 4        22       30        304        60           3 hours     30

# %%
data["Time since posted"]=data["Time since posted"].str.extract('(\d+)').astype(int)

# %%
data.head()
# Out:
#    USERNAME  Caption  Followers  Hashtags  Time since posted  Likes
# 0        61       86       1600        14                 11    139
# 1        28       82        880        91                  2     23
# 2         3       13        255        82                  2     25
# 3        67       89        340        61                  3     49
# 4        22       30        304        60                  3     30

# %%
X=data.drop(labels=["Time since posted","Likes"],axis=1)

# %%
y=data[["Time since posted","Likes"]]

# %%
y.head()
# Out:
#    Time since posted  Likes
# 0                 11    139
# 1                  2     23
# 2                  2     25
# 3                  3     49
# 4                  3     30

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=30)

# %%
X_train.shape
# Out:
# (75, 4)

# %%
y_train.shape
# Out:
# (75, 2)

# %%
X_test.shape
# Out:
# (19, 4)

# %%
y_test.shape
# Out:
# (19, 2)

# %%
s=StandardScaler()

# %%
X_train_scaled=s.fit_transform(X_train)
X_test_scaled=s.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet

# %%
models={
    "LinearRegression":LinearRegression(),
    "Ridge":Ridge(),
    "Lasso":Lasso(),
    "ElasticNet":ElasticNet()
}

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
for i in range(len(models)):
    model=list(models.values())[i]
    print(model)
# Out:
# LinearRegression()
# Ridge()
# Lasso()
# ElasticNet()

# %%
def evaluate_models(act,pred):
    
    R2Score=r2_score(act,pred)
    MAE=mean_absolute_error(act,pred)
    MSE=mean_squared_error(act,pred)
    
    return R2Score,MAE,MSE

# %%
rscore=[]
for i in range(len(models)):
    model=list(models.values())[i]
    model.fit(X_train,y_train)
    
    pred=model.predict(X_test)
    
    R2Score,MAE,MSE=evaluate_models(y_test,pred)
    
    rscore.append(R2Score)
    print(list(models.keys())[i])
    print("r2score= ",R2Score)
    print("MAE =",MAE)
    print("MSE =",MSE)
    print(50*"=")
# Out:
# LinearRegression
# r2score=  0.04788800048357511
# MAE = 19.01821816432475
# MSE = 1778.5900382078128
# ==================================================
# Ridge
# r2score=  0.047888811794566666
# MAE = 19.01819886163117
# MSE = 1778.5944223946417
# ==================================================
# Lasso
# r2score=  0.06368619584876112
# MAE = 18.992054303651287
# MSE = 1779.0799231042556
# ==================================================
# ElasticNet
# r2score=  0.05596859158165629
# MAE = 19.004421998620355
# MSE = 1778.997988920816
# ==================================================

# %%
eval_dict={key:value for value,key in zip(rscore,models.values())}

# %%
eval_dict
# Out:
# {LinearRegression(): 0.04788800048357511,
#  Ridge(): 0.047888811794566666,
#  Lasso(): 0.06368619584876112,
#  ElasticNet(): 0.05596859158165629}

# %%
eval_dict.values()
# Out:
# dict_values([0.04788800048357511, 0.047888811794566666, 0.06368619584876112, 0.05596859158165629])

# %%
best_score=max(rscore)

# %%
for key,value in eval_dict.items():
    if value==best_score:
        best_model=key
        break

# %%
best_model.fit(X_train,y_train)
# Out:
# Lasso()

# %%
import pickle
with open ("Best_model.pkl","wb") as f:
    pickle.dump(best_model,f)
